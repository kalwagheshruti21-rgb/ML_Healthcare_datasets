# %% [markdown]
# Decision tree classifier - Diabetes data set

# %% [markdown]
# Task: Implement Decision tree classifier ML model on customer churn dataset to predict pattient has diabetes or not
# Domain: healthcare

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('diabetes (2).xls')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (768, 9)

# %%
df.size
# Out:
# 6912

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
for i in df.columns:
    if(df[i].dtype!='object'):
        sns.boxplot(df[i])
        plt.title(i)
        plt.show()

# %%
out_cols=['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']
for i in out_cols:
    q1=df[i].quantile(0.25)
    q3=df[i].quantile(0.75)
    iqr=q3-q1
    lb=q1-1.5*iqr
    ub=q3+1.5*iqr
    df=df[(df[i]>=lb) & (df[i]<=ub)]

# %%
for i in df.columns:
    if(df[i].dtype!='object'):
        sns.boxplot(df[i])
        plt.title(i)
        plt.show()

# %%
x=df.drop('Outcome',axis=1)
y=df['Outcome']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (508, 8)
# (128, 8)
# (508,)
# (128,)

# %%
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier()
tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=tree.predict(x_test)

# %%
res=pd.DataFrame({'actual':y_test,'predicted':y_pred,'error':y_test-y_pred,'error_square':(y_test-y_pred)**2})
res.head(10)
# Out:
#      actual  predicted  error  error_square
# 338       1          1      0             0
# 763       0          0      0             0
# 104       0          0      0             0
# 437       0          0      0             0
# 184       0          1     -1             1
# 726       0          0      0             0
# 70        1          0      1             1
# 109       1          0      1             1
# 694       0          0      0             0
# 274       0          0      0             0

# %%
from sklearn.metrics import *
cm=confusion_matrix(y_test,y_pred)
print("Confusion matrix:\n",cm)
# Out:
# Confusion matrix:
#  [[76 16]
#  [15 21]]

# %%
print("Classification Report:\n",classification_report(y_test,y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.83      0.83        92
#            1       0.57      0.58      0.58        36
#
#     accuracy                           0.76       128
#    macro avg       0.70      0.70      0.70       128
# weighted avg       0.76      0.76      0.76       128
